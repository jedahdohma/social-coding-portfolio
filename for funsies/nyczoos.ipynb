# %%
print("welcome to new york city. we have many wonderful animal exhibits you can visit.")

borough = input("which borough would you like to explore? ").strip().lower()
#BRONX
if borough == "the bronx" or borough == "bronx":
  print("come visit the bronx zoo!")
  print("it is located in the bronx park at 2300 southern boulevard, bronx, ny 10460.")
  print("their phone number is (718) 367-1010 and their website is https://bronxzoo.com/")
  import random
  bronxroster = ['aardvark','african painted dog','aldabra tortoise','american alligator','american bison','amur tiger','anaconda','andean condor','asian elephant','baby doll sheep','bald eagle','blue iguana','boer goat','california sea lion','caribbean flamingo','chinchilla','collared lemur','coquerels sifaka','cuban amazon parrot','dhole','ebony langur','fennec fox','fossa','gelada','giant anteater','giraffe','gorilla','grizzly bear','henkels leaf-tailed gecko','indian gharial','greater one-horned rhino','king cobra','king vulture','komodo dragon','linnes two-toed sloth','lion','little penguin','madagascar tree boa','magellanic penguin','malayan tapir','malayan tiger','matschies tree kangaroo','mini donkey','monarch butterfly','nile crocodile','north american porcupine','nubian ibex','okapi','poison dart frog','pygmy marmoset','radiated tortoise','red panda','red ruffed lemur','ring-tailed lemur','ring-tailed mongoose','rock hyrax','small clawed asian otter','snow leopard','snowy owl','southern white-faced owl','southern white rhinoceros','squirrel monkey','tufted puffin','white cheeked gibbon','white-throated bee eater','zebra']
  selected_item = random.choice(bronxroster)
  print("there are many animals to observe and learn about, like the", selected_item,"...")
  if selected_item == "aardvark":
    print("for more information, visit https://en.wikipedia.org/wiki/Aardvark")
  elif selected_item == "african painted dog":
    print("for more information, visit https://en.wikipedia.org/wiki/African_wild_dog")
  elif selected_item == "aldabra tortoise":
    print("for more information, visit https://en.wikipedia.org/wiki/Aldabra_giant_tortoise")
  elif selected_item == "american alligator":
    print("for more information, visit https://en.wikipedia.org/wiki/American_alligator")
  elif selected_item == "american bison":
    print("for more information, visit https://en.wikipedia.org/wiki/American_bison")
  elif selected_item == "amur tiger":
    print("for more information, visit https://en.wikipedia.org/wiki/Amur_tiger")
  elif selected_item == "anaconda":
    print("for more information, visit https://en.wikipedia.org/wiki/Anaconda")
  elif selected_item == "andean condor":
    print("for more information, visit https://en.wikipedia.org/wiki/Andean_condor")
  elif selected_item == "asian elephant":
    print("for more information, visit https://en.wikipedia.org/wiki/Asian_elephant")
  elif selected_item == "baby doll sheep":
    print("for more information, visit https://en.wikipedia.org/wiki/Baby_doll_sheep")
  elif selected_item == "bald eagle":
    print("for more information, visit https://en.wikipedia.org/wiki/Bald_eagle")
  elif selected_item == "blue iguana":
    print("for more information, visit https://en.wikipedia.org/wiki/Blue_iguana")
  elif selected_item == "boer goat":
    print("for more information, visit https://en.wikipedia.org/wiki/Boer_goat")
  elif selected_item == "california sea lion":
    print("for more information, visit https://en.wikipedia.org/wiki/California_sea_lion")
  elif selected_item == "caribbean flamingo":
    print("for more information, visit https://en.wikipedia.org/wiki/Caribbean_flamingo")
  elif selected_item == "chinchilla":
    print("for more information, visit https://en.wikipedia.org/wiki/Chinchilla")
  elif selected_item == "collared lemur":
    print("for more information, visit https://en.wikipedia.org/wiki/Collared_lemur")
  elif selected_item == "coquerels sifaka":
    print("for more information, visit https://en.wikipedia.org/wiki/Coquerel%27s_sifaka")
  elif selected_item == "cuban amazon parrot":
    print("for more information, visit https://en.wikipedia.org/wiki/Amazon_parrot")
  elif selected_item == "dhole":
    print("for more information, visit https://en.wikipedia.org/wiki/Dhole")
  elif selected_item == "ebony langur":
    print("for more information, visit https://en.wikipedia.org/wiki/East_Javan_langur")
  elif selected_item == "fennec fox":
    print("for more information, visit https://en.wikipedia.org/wiki/Fennec_fox")
  elif selected_item == "fossa":
    print("for more information, visit https://en.wikipedia.org/wiki/Fossa")
  elif selected_item == "gelada":
    print("for more information, visit https://en.wikipedia.org/wiki/Gelada")
  elif selected_item == "giant anteater":
    print("for more information, visit https://en.wikipedia.org/wiki/Giant_anteater")
  elif selected_item == "giraffe":
    print("for more information, visit https://en.wikipedia.org/wiki/Giraffe")
  elif selected_item == "gorilla":
    print("for more information, visit https://en.wikipedia.org/wiki/Gorilla")
  elif selected_item == "grizzly bear":
    print("for more information, visit https://en.wikipedia.org/wiki/Grizzly_bear")
  elif selected_item == "henkels leaf-tailed gecko":
    print("for more information, visit https://en.wikipedia.org/wiki/Henkel%27s_leaf-tailed_gecko")
  elif selected_item == "indian gharial":
    print("for more information, visit https://en.wikipedia.org/wiki/Indian_gharial")
  elif selected_item == "greater one-horned rhino":
    print("for more information, visit https://en.wikipedia.org/wiki/Indian_rhinoceros")
  elif selected_item == "king cobra":
    print("for more information, visit https://en.wikipedia.org/wiki/King_cobra")
  elif selected_item == "king vulture":
    print("for more information, visit https://en.wikipedia.org/wiki/King_vulture")
  elif selected_item == "komodo dragon":
    print("for more information, visit https://en.wikipedia.org/wiki/Komodo_dragon")
  elif selected_item == "linnes two-toed sloth":
    print("for more information, visit https://en.wikipedia.org/wiki/Linnaeus%27s_two-toed_sloth")
  elif selected_item == "lion":
    print("for more information, visit https://en.wikipedia.org/wiki/Lion")
  elif selected_item == "little penguin":
    print("for more information, visit https://en.wikipedia.org/wiki/Little_penguin")
  elif selected_item == "madagascar tree boa":
    print("for more information, visit https://en.wikipedia.org/wiki/Madagascar_tree_boa")
  elif selected_item == "magellanic penguin":
    print("for more information, visit https://en.wikipedia.org/wiki/Magellanic_penguin")
  elif selected_item == "malayan tapir":
    print("for more information, visit https://en.wikipedia.org/wiki/Malayan_tapir")
  elif selected_item == "malayan tiger":
    print("for more information, visit https://en.wikipedia.org/wiki/Malayan_tiger")
  elif selected_item == "matschies tree kangaroo":
    print("for more information, visit https://en.wikipedia.org/wiki/Matchie%27s_tree-kangaroo")
  elif selected_item == "mini donkey":
    print("for more information, visit https://en.wikipedia.org/wiki/North_American_donkeys")
  elif selected_item == "monarch butterfly":
    print("for more information, visit https://en.wikipedia.org/wiki/Monarch_butterfly")
  elif selected_item == "nile crocodile":
    print("for more information, visit https://en.wikipedia.org/wiki/Nile_crocodile")
  elif selected_item == "north american porcupine":
    print("for more information, visit https://en.wikipedia.org/wiki/North_American_porcupine")
  elif selected_item == "nubian ibex":
    print("for more information, visit https://en.wikipedia.org/wiki/Nubian_ibex")
  elif selected_item == "okapi":
    print("for more information, visit https://en.wikipedia.org/wiki/Okapi")
  elif selected_item == "poison dart frog":
    print("for more information, visit https://en.wikipedia.org/wiki/Poison_dart_frog")
  elif selected_item == "pygmy marmoset":
    print("for more information, visit https://en.wikipedia.org/wiki/Pygmy_marmoset")
  elif selected_item == "radiated tortoise":
    print("for more information, visit https://en.wikipedia.org/wiki/Radiated_tortoise")
  elif selected_item == "red panda":
    print("for more information, visit https://en.wikipedia.org/wiki/Red_panda")
  elif selected_item == "red ruffed lemur":
    print("for more information, visit https://en.wikipedia.org/wiki/Red-ruffed_lemur")
  elif selected_item == "ring-tailed lemur":
    print("for more information, visit https://en.wikipedia.org/wiki/Ring-tailed_lemur")
  elif selected_item == "ring-tailed mongoose":
    print("for more information, visit https://en.wikipedia.org/wiki/Ring-tailed_mongoose")
  elif selected_item == "rock hyrax":
    print("for more information, visit https://en.wikipedia.org/wiki/Rock_hyrax")
  elif  selected_item == "snow leopard":
    print("for more information, visit https://en.wikipedia.org/wiki/Snow_leopard")
  elif selected_item == "snowy owl":
    print("for more information, visit https://en.wikipedia.org/wiki/Snowy_owl")
  elif selected_item == "southern white-faced owl":
    print("for more information, visit https://en.wikipedia.org/wiki/Southern_white-faced_owl")
  elif selected_item == "southern white rhinoceros":
    print("for more information, visit https://en.wikipedia.org/wiki/Southern_white_rhinoceros")
  elif selected_item == "squirrel monkey":
    print("for more information, visit https://en.wikipedia.org/wiki/Squirrel_monkey")
  elif selected_item == "tufted puffin":
    print("for more information, visit https://en.wikipedia.org/wiki/Tufted_puffin")
  elif selected_item == "white cheeked gibbon":
    print("for more information, visit https://en.wikipedia.org/wiki/White-cheeked_gibbon")
  elif selected_item == "white-throated bee eater":
    print("for more information, visit https://en.wikipedia.org/wiki/White-throated_bee-eater")
  elif selected_item == "zebra":
    print("for more information, visit https://en.wikipedia.org/wiki/Zebra")
#BROOKLYN
if borough == "brooklyn":
  print("you have two choices in brooklyn:")
  print("you could either visit an aquarium or a wildlife center.")
  brooklynexhibit = input("do you want to go to the aquarium or the wildlife center? ").strip().lower()
  if brooklynexhibit == "aquarium" or brooklynexhibit == "the aquarium":
    print("come visit the new york aquarium!")
    print("it is located on the coney island beach & boardwalk at surf avenue & west 8th street, brooklyn, ny 11224.")
    print("their phone number is (718) 265-3474 and their website is https://nyaquarium.com/")
    import random
    aquariumroster = ['black-footed penguin','california sea lion','cownose ray','green moray eel','harbor seal','sand tiger shark','sea otter']
    selected_item = random.choice(aquariumroster)
    print("there are many animals to observe and learn about, like the", selected_item,"...")
    if selected_item == "black-footed penguin":
      print("for more information, visit https://en.wikipedia.org/wiki/Black-footed_penguin")
    elif selected_item == "california sea lion":
      print("for more information, visit https://en.wikipedia.org/wiki/California_sea_lion")
    elif selected_item == "cownose ray":
      print("for more information, visit https://en.wikipedia.org/wiki/Cownose_ray")
    elif selected_item == "green moray eel":
      print("for more information, visit https://en.wikipedia.org/wiki/Green_moray_eel")
    elif selected_item == "harbor seal":
      print("for more information, visit https://en.wikipedia.org/wiki/Harbor_seal")
    elif selected_item == "sand tiger shark":
      print("for more information, visit https://en.wikipedia.org/wiki/Sand_tiger_shark")
    elif selected_item == "sea otter":
      print("for more information, visit https://en.wikipedia.org/wiki/Sea_otter")
  if brooklynexhibit == "wildlife center" or brooklynexhibit == "wildlife":
    print("come visit the prospect park wildlife center!")
    print("it is located in prospect park at 450 flatbush avenue, brooklyn, ny 11225.")
    print("their phone number is (718) 399-7339 and their website is https://prospectparkzoo.com/")
    import random
    brooklynroster = ['alpaca','california sea lion','dingo','dwarf mongoose','emu','geoffroys marmoset','golden lion tamarin','hamadryas baboon','miniature horse','north american porcupine','north american river otter','manul','poison dart frog','red-crested turaco','red panda','shetland sheep','tufted deer','vietnamese mossy frog','wreathed hornbill','sand cat']
    selected_item = random.choice(brooklynroster)
    print("there are many animals to observe and learn about, like the", selected_item,"...")
    if selected_item == "alpaca":
      print("for more information, visit https://en.wikipedia.org/wiki/Alpaca")
    elif selected_item == "california sea lion":
      print("for more information, visit https://en.wikipedia.org/wiki/California_sea_lion")
    elif selected_item == "dingo":
      print("for more information, visit https://en.wikipedia.org/wiki/Dingo")
    elif selected_item == "dwarf mongoose":
      print("for more information, visit https://en.wikipedia.org/wiki/Dwarf_mongoose")
    elif selected_item == "emu":
      print("for more information, visit https://en.wikipedia.org/wiki/Emu")
    elif selected_item == "geoffroys marmoset":
      print("for more information, visit https://en.wikipedia.org/wiki/White-headed_marmoset")
    elif selected_item == "golden lion tamarin":
      print("for more information, visit https://en.wikipedia.org/wiki/Golden_lion_tamarin")
    elif selected_item == "hamadryas baboon":
      print("for more information, visit https://en.wikipedia.org/wiki/Hamadryas_baboon")
    elif selected_item == "miniature horse":
      print("for more information, visit https://en.wikipedia.org/wiki/Miniature_horse")
    elif selected_item == "north american porcupine":
      print("for more information, visit https://en.wikipedia.org/wiki/North_American_porcupine")
    elif selected_item == "north american river otter":
      print("for more information, visit https://en.wikipedia.org/wiki/North_American_river_otter")
    elif selected_item == "manul":
      print("for more information, visit https://en.wikipedia.org/wiki/Pallas_cat")
    elif selected_item == "poison dart frog":
      print("for more information, visit https://en.wikipedia.org/wiki/Poison_dart_frog")
    elif selected_item == "red-crested turaco":
      print("for more information, visit https://en.wikipedia.org/wiki/Red-crested_turaco")
    elif selected_item == "red panda":
      print("for more information, visit https://en.wikipedia.org/wiki/Red_panda")
    elif selected_item == "shetland sheep":
      print("for more information, visit https://en.wikipedia.org/wiki/Shetland_sheep")
    elif selected_item == "tufted deer":
      print("for more information, visit https://en.wikipedia.org/wiki/Tufted_deer")
    elif selected_item == "vietnamese mossy frog":
      print("for more information, visit https://en.wikipedia.org/wiki/Theloderma_corticale")
    elif selected_item == "wreathed hornbill":
      print("for more information, visit https://en.wikipedia.org/wiki/Wreathed_hornbill")
    elif selected_item == "sand cat":
      print("for more information, visit https://en.wikipedia.org/wiki/Sand_cat")
#MANHATTAN
if borough == "manhattan":
  print("acome visit the central park wildlife center & tisch children's zoo!")
  print("it is located in central park at 5th avenue & east 64th street, new york, ny 10021.")
  print("their phone number is (212) 439-6500 and their website is https://centralparkzoo.com/")
  import random
  manhattanroster = ['california sea lion','chinstrap penguin','gentoo penguin','grizzly bear','king penguin','macaroni penguin','red panda','ruffed lemur','snow leopard','snow monkey']
  selected_item = random.choice(manhattanroster)
  print("there are many animals to observe and learn about, like the", selected_item,"...")
  if selected_item == "california sea lion":
    print("for more information, visit https://en.wikipedia.org/wiki/California_sea_lion")
  elif selected_item == "chinstrap penguin":
    print("for more information, visit https://en.wikipedia.org/wiki/Chinstrap_penguin")
  elif selected_item == "gentoo penguin":
    print("for more information, visit https://en.wikipedia.org/wiki/Gentoo_penguin")
  elif selected_item == "grizzly bear":
    print("for more information, visit https://en.wikipedia.org/wiki/Grizzly_bear")
  elif selected_item == "king penguin":
    print("for more information, visit https://en.wikipedia.org/wiki/King_penguin")
  elif selected_item == "macaroni penguin":
    print("for more information, visit https://en.wikipedia.org/wiki/Macaroni_penguin")
  elif selected_item == "red panda":
    print("for more information, visit https://en.wikipedia.org/wiki/Red_panda")
  elif selected_item == "ruffed lemur":
    print("for more information, visit https://en.wikipedia.org/wiki/Ruffed_lemur")
  elif selected_item == "snow leopard":
    print("for more information, visit https://en.wikipedia.org/wiki/Snow_leopard")
  elif selected_item == "snow monkey":
    print("for more information, visit https://en.wikipedia.org/wiki/Snow_monkey")
#QUEENS
if borough == "queens":
  print("come visit the queens wildlife center!")
  print("it is located in flushing meadows corona park at 53-51 111th street, flushing, ny 11368.")
  print("their phone number is (718) 271-1500 and their website is https://queenszoo.com/")
  import random
  queensroster = ['american alligator','american bison','andean bear','bald eagle','belted galloway','bobwhite quail','california sea lion','canadian lynx','cattle egret','coyote','flemish giant rabbit','puma','roosevelt elk','southern pudu','texas longhorn','thick-billed parrot','highland cattle']
  selected_item = random.choice(queensroster)
  print("there are many animals to observe and learn about, like the", selected_item,"...")
  if selected_item == "american alligator":
    print("for more information, visit https://en.wikipedia.org/wiki/American_alligator")
  elif selected_item == "american bison":
    print("for more information, visit https://en.wikipedia.org/wiki/American_bison")
  elif selected_item == "andean bear":
    print("for more information, visit https://en.wikipedia.org/wiki/Andean_bear")
  elif selected_item == "bald eagle":
    print("for more information, visit https://en.wikipedia.org/wiki/Bald_eagle")
  elif selected_item == "belted galloway":
    print("for more information, visit https://en.wikipedia.org/wiki/Belted_Galloway")
  elif selected_item == "bobwhite quail":
    print("for more information, visit https://en.wikipedia.org/wiki/Bobwhite_quail")
  elif selected_item == "california sea lion":
    print("for more information, visit https://en.wikipedia.org/wiki/California_sea_lion")
  elif selected_item == "canadian lynx":
    print("for more information, visit https://en.wikipedia.org/wiki/Canadian_lynx")
  elif selected_item == "cattle egret":
    print("for more information, visit https://en.wikipedia.org/wiki/Cattle_egret")
  elif selected_item == "coyote":
    print("for more information, visit https://en.wikipedia.org/wiki/Coyote")
  elif selected_item == "flemish giant rabbit":
    print("for more information, visit https://en.wikipedia.org/wiki/Flemish_Giant_rabbit")
  elif selected_item == "puma":
    print("for more information, visit https://en.wikipedia.org/wiki/Puma_(species)")
  elif selected_item == "roosevelt elk":
    print("for more information, visit https://en.wikipedia.org/wiki/Roosevelt_elk")
  elif selected_item == "southern pudu":
    print("for more information, visit https://en.wikipedia.org/wiki/Southern_pudu")
  elif selected_item == "texas longhorn":
    print("for more information, visit https://en.wikipedia.org/wiki/Texas_longhorn")
  elif selected_item == "thick-billed parrot":
    print("for more information, visit https://en.wikipedia.org/wiki/Thick-billed_parrot")
  elif  selected_item == "highland cattle":
    print("for more information, visit https://en.wikipedia.org/wiki/Highland_cattle")
#STATEN ISLAND
if borough == "staten island":
  print("come visit the staten island zoo!")
  print("it is located in barrett park at 614 broadway, staten island, ny 10310.")
  print("their phone number is (718) 442-3100 and their website is https://statenislandzoo.org/")
  import random
  statenislandroster = ['spider monkeys','patagonian cavy','groundhog','chinese alligator','red kangaroo','tawny frogmouth','serval','highland cow','fennec fox','capybara','donkey','green anaconda','emu','ibex','sloth','ostrich','binturong','roadrunner','bearded dragon','meerkat','amur leopard','southern ground hornbill','pacu']
  selected_item = random.choice(statenislandroster)
  print("there are many animals to observe and learn about, like the", selected_item,"...")
  if selected_item == "spider monkeys":
    print("for more information, visit https://en.wikipedia.org/wiki/Spider_monkey")
  elif selected_item == "patagonian cavy":
    print("for more information, visit https://en.wikipedia.org/wiki/Patagonian_cavy")
  elif selected_item == "groundhog":
    print("for more information, visit https://en.wikipedia.org/wiki/Groundhog")
  elif selected_item == "chinese alligator":
    print("for more information, visit https://en.wikipedia.org/wiki/Chinese_alligator")
  elif selected_item == "red kangaroo":
    print("for more information, visit https://en.wikipedia.org/wiki/Red_kangaroo")
  elif selected_item == "tawny frogmouth":
    print("for more information, visit https://en.wikipedia.org/wiki/Tawny_frogmouth")
  elif selected_item == "serval":
    print("for more information, visit https://en.wikipedia.org/wiki/Serval")
  elif selected_item == "highland cow":
    print("for more information, visit https://en.wikipedia.org/wiki/Highland_cow")
  elif selected_item == "fennec fox":
    print("for more information, visit https://en.wikipedia.org/wiki/Fennec_fox")
  elif selected_item == "capybara":
    print("for more information, visit https://en.wikipedia.org/wiki/Capybara")
  elif selected_item == "donkey":
    print("for more information, visit https://en.wikipedia.org/wiki/Donkey")
  elif selected_item == "green anaconda":
    print("for more information, visit https://en.wikipedia.org/wiki/Green_anaconda")
  elif selected_item == "emu":
    print("for more information, visit https://en.wikipedia.org/wiki/Emu")
  elif selected_item == "ibex":
    print("for more information, visit https://en.wikipedia.org/wiki/Ibex")
  elif selected_item == "sloth":
    print("for more information, visit https://en.wikipedia.org/wiki/Sloth")
  elif selected_item == "ostrich":
    print("for more information, visit https://en.wikipedia.org/wiki/Ostrich")
  elif selected_item == "binturong":
    print("for more information, visit https://en.wikipedia.org/wiki/Binturong")
  elif selected_item == "roadrunner":
    print("for more information, visit https://en.wikipedia.org/wiki/Roadrunner")
  elif selected_item == "bearded dragon":
    print("for more information, visit https://en.wikipedia.org/wiki/Bearded_dragon")
  elif selected_item == "meerkat":
    print("for more information, visit https://en.wikipedia.org/wiki/Meerkat")
  elif selected_item == "amur leopard":
    print("for more information, visit https://en.wikipedia.org/wiki/Amur_leopard")
  elif selected_item == "southern ground hornbill":
    print("for more information, visit https://en.wikipedia.org/wiki/Southern_ground_hornbill")
  elif selected_item == "pacu":
    print("for more information, visit https://en.wikipedia.org/wiki/Pacu")
#ALTERNATE CHOICE
else:
  print("is that in new jersey?")
# Out:
# welcome to new york city. we have many wonderful animal exhibits you can visit.
# which borough would you like to explore? staten island
# come visit the staten island zoo!
# it is located in barrett park at 614 broadway, staten island, ny 10310.
# their phone number is (718) 442-3100 and their website is https://statenislandzoo.org/
# there are many animals to observe and learn about, like the southern ground hornbill ...
# for more information, visit https://en.wikipedia.org/wiki/Southern_ground_hornbill
